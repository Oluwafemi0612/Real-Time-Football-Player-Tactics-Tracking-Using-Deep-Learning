# %%
import supervision as sv
print(sv.__version__)
# Out:
# 0.27.0.post2

# %% [markdown]
# # Football Analysis Pipeline
#
# This notebook processes football videos to detect players, track them, assign teams, and generate annotated output videos with bounding boxes, speed, and distance metrics.
#
# ## Setup
# Make sure you have the required dependencies installed:
# - ultralytics
# - supervision
# - opencv-python
# - pandas
# - numpy
# - imageio
#
# Place your input video in the `input_videos/` folder and your trained YOLO model in `models/best.pt`.
#
# ## How to Use
# 1. Place your video files in the `input_videos/` folder
# 2. Run the video selection cell below to choose your input video
# 3. Modify the configuration as needed
# 4. Run all cells in order
# 5. The annotated video will be saved to `output_videos/output_video.avi`

# %%
# Import required libraries
from utils import read_video, save_video
from trackers import Tracker
import cv2
import numpy as np
from team_assigner import TeamAssigner
from player_ball_assigner import PlayerBallAssigner
from camera_movement_estimator import CameraMovementEstimator
from view_transformer import ViewTransformer
from speed_and_distance_estimator import SpeedAndDistance_Estimator
import os
import glob

# %%
# Video Selection
print("Available videos in input_videos/:")
video_files = glob.glob('input_videos/*.mp4') + glob.glob('input_videos/*.avi') + glob.glob('input_videos/*.mov')
for i, video in enumerate(video_files):
    print(f"{i+1}. {os.path.basename(video)}")

# Select video by index (change this number)
selected_index = 1  # Change to 1, 2, 3, etc. for different videos

if video_files:
    INPUT_VIDEO_PATH = video_files[selected_index]
    print(f"\nSelected video: {os.path.basename(INPUT_VIDEO_PATH)}")
else:
    INPUT_VIDEO_PATH = 'input_videos/08fd33_4.mp4'  # Default
    print("No videos found, using default path")
# Out:
# Available videos in input_videos/:
# 1. 08fd33_4.mp4
# 2. E3c993bd2_0 (74).mp4
#
# Selected video: E3c993bd2_0 (74).mp4

# %%
# Configuration
MODEL_PATH = 'models/best.pt'
OUTPUT_VIDEO_PATH = 'output_videos/output_video.avi'
STUB_PATH = 'stubs/track_stubs.pkl'
READ_FROM_STUB = False  # Set to True to skip detection if stubs exist

print(f"Input: {INPUT_VIDEO_PATH}")
print(f"Output: {OUTPUT_VIDEO_PATH}")
# Out:
# Input: input_videos\E3c993bd2_0 (74).mp4
# Output: output_videos/output_video.avi

# %%
# Step 1: Read the input video
print("Reading video...")
video_frames = read_video(INPUT_VIDEO_PATH)
print(f"✓ Loaded {len(video_frames)} frames")
# Out:
# Reading video...
# Read 100 frames
# Read 200 frames
# Read 300 frames
# Read 400 frames
# Read 500 frames
# Read 600 frames
# Read 700 frames
# EOF reached at frame 750
# Total frames read: 750
# ✓ Loaded 750 frames

# %%
# Step 2: Initialize tracker and get object tracks
print("Initializing tracker...")
tracker = Tracker(MODEL_PATH)

print("Getting object tracks...")
tracks = tracker.get_object_tracks(video_frames,
                                   read_from_stub=READ_FROM_STUB,
                                   stub_path=STUB_PATH)
# Out:
# Initializing tracker...
# Getting object tracks...
# [YOLO] Processing frames 1/750
# [YOLO] Processing frames 2/750
# [YOLO] Processing frames 3/750
# [YOLO] Processing frames 4/750
# [YOLO] Processing frames 5/750
# [YOLO] Processing frames 6/750
# [YOLO] Processing frames 7/750
# [YOLO] Processing frames 8/750
# [YOLO] Processing frames 9/750
# [YOLO] Processing frames 10/750
# [YOLO] Processing frames 11/750
# [YOLO] Processing frames 12/750
# [YOLO] Processing frames 13/750
# [YOLO] Processing frames 14/750
# [YOLO] Processing frames 15/750
# [YOLO] Processing frames 16/750
# [YOLO] Processing frames 17/750
# [YOLO] Processing frames 18/750
# [YOLO] Processing frames 19/750
# [YOLO] Processing frames 20/750
# [YOLO] Processing frames 21/750
# [YOLO] Processing frames 22/750
# [YOLO] Processing frames 23/750
# [YOLO] Processing frames 24/750
# [YOLO] Processing frames 25/750
# [YOLO] Processing frames 26/750
# [YOLO] Processing frames 27/750
# [YOLO] Processing frames 28/750
# [YOLO] Processing frames 29/750
# [YOLO] Processing frames 30/750
# [YOLO] Processing frames 31/750
# [YOLO] Processing frames 32/750
# [YOLO] Processing frames 33/750
# [YOLO] Processing frames 34/750
# [YOLO] Processing frames 35/750
# [YOLO] Processing frames 36/750
# [YOLO] Processing frames 37/750
# [YOLO] Processing frames 38/750
# [YOLO] Processing frames 39/750
# [YOLO] Processing frames 40/750
# [YOLO] Processing frames 41/750
# [YOLO] Processing frames 42/750
# [YOLO] Processing frames 43/750
# [YOLO] Processing frames 44/750
# [YOLO] Processing frames 45/750
# [YOLO] Processing frames 46/750
# [YOLO] Processing frames 47/750
# [YOLO] Processing frames 48/750
# [YOLO] Processing frames 49/750
# [YOLO] Processing frames 50/750
# [YOLO] Processing frames 51/750
# [YOLO] Processing frames 52/750
# [YOLO] Processing frames 53/750
# [YOLO] Processing frames 54/750
# [YOLO] Processing frames 55/750
# [YOLO] Processing frames 56/750
# [YOLO] Processing frames 57/750
# [YOLO] Processing frames 58/750
# [YOLO] Processing frames 59/750
# [YOLO] Processing frames 60/750
# [YOLO] Processing frames 61/750
# [YOLO] Processing frames 62/750
# [YOLO] Processing frames 63/750
# [YOLO] Processing frames 64/750
# [YOLO] Processing frames 65/750
# [YOLO] Processing frames 66/750
# [YOLO] Processing frames 67/750
# [YOLO] Processing frames 68/750
# [YOLO] Processing frames 69/750
# [YOLO] Processing frames 70/750
# [YOLO] Processing frames 71/750
# [YOLO] Processing frames 72/750
# [YOLO] Processing frames 73/750
# [YOLO] Processing frames 74/750
# [YOLO] Processing frames 75/750
# [YOLO] Processing frames 76/750
# [YOLO] Processing frames 77/750
# [YOLO] Processing frames 78/750
# [YOLO] Processing frames 79/750
# [YOLO] Processing frames 80/750
# [YOLO] Processing frames 81/750
# [YOLO] Processing frames 82/750
# [YOLO] Processing frames 83/750
# [YOLO] Processing frames 84/750
# [YOLO] Processing frames 85/750
# [YOLO] Processing frames 86/750
# [YOLO] Processing frames 87/750
# [YOLO] Processing frames 88/750
# [YOLO] Processing frames 89/750
# [YOLO] Processing frames 90/750
# [YOLO] Processing frames 91/750
# [YOLO] Processing frames 92/750
# [YOLO] Processing frames 93/750
# [YOLO] Processing frames 94/750
# [YOLO] Processing frames 95/750
# [YOLO] Processing frames 96/750
# [YOLO] Processing frames 97/750
# [YOLO] Processing frames 98/750
# [YOLO] Processing frames 99/750
# [YOLO] Processing frames 100/750
# [YOLO] Processing frames 101/750
# [YOLO] Processing frames 102/750
# [YOLO] Processing frames 103/750
# [YOLO] Processing frames 104/750
# [YOLO] Processing frames 105/750
# [YOLO] Processing frames 106/750
# [YOLO] Processing frames 107/750
# [YOLO] Processing frames 108/750
# [YOLO] Processing frames 109/750
# [YOLO] Processing frames 110/750
# [YOLO] Processing frames 111/750
# [YOLO] Processing frames 112/750
# [YOLO] Processing frames 113/750
# [YOLO] Processing frames 114/750
# [YOLO] Processing frames 115/750
# [YOLO] Processing frames 116/750
# [YOLO] Processing frames 117/750
# [YOLO] Processing frames 118/750
# [YOLO] Processing frames 119/750
# [YOLO] Processing frames 120/750
# [YOLO] Processing frames 121/750
# [YOLO] Processing frames 122/750
# [YOLO] Processing frames 123/750
# [YOLO] Processing frames 124/750
# [YOLO] Processing frames 125/750
# [YOLO] Processing frames 126/750
# [YOLO] Processing frames 127/750
# [YOLO] Processing frames 128/750
# [YOLO] Processing frames 129/750
# [YOLO] Processing frames 130/750
# [YOLO] Processing frames 131/750
# [YOLO] Processing frames 132/750
# [YOLO] Processing frames 133/750
# [YOLO] Processing frames 134/750
# [YOLO] Processing frames 135/750
# [YOLO] Processing frames 136/750
# [YOLO] Processing frames 137/750
# [YOLO] Processing frames 138/750
# [YOLO] Processing frames 139/750
# [YOLO] Processing frames 140/750
# [YOLO] Processing frames 141/750
# [YOLO] Processing frames 142/750
# [YOLO] Processing frames 143/750
# [YOLO] Processing frames 144/750
# [YOLO] Processing frames 145/750
# [YOLO] Processing frames 146/750
# [YOLO] Processing frames 147/750
# [YOLO] Processing frames 148/750
# [YOLO] Processing frames 149/750
# [YOLO] Processing frames 150/750
# [YOLO] Processing frames 151/750
# [YOLO] Processing frames 152/750
# [YOLO] Processing frames 153/750
# [YOLO] Processing frames 154/750
# [YOLO] Processing frames 155/750
# [YOLO] Processing frames 156/750
# [YOLO] Processing frames 157/750
# [YOLO] Processing frames 158/750
# [YOLO] Processing frames 159/750
# [YOLO] Processing frames 160/750
# [YOLO] Processing frames 161/750
# [YOLO] Processing frames 162/750
# [YOLO] Processing frames 163/750
# [YOLO] Processing frames 164/750
# [YOLO] Processing frames 165/750
# [YOLO] Processing frames 166/750
# [YOLO] Processing frames 167/750
# [YOLO] Processing frames 168/750
# [YOLO] Processing frames 169/750
# [YOLO] Processing frames 170/750
# [YOLO] Processing frames 171/750
# [YOLO] Processing frames 172/750
# [YOLO] Processing frames 173/750
# [YOLO] Processing frames 174/750
# [YOLO] Processing frames 175/750
# [YOLO] Processing frames 176/750
# [YOLO] Processing frames 177/750
# [YOLO] Processing frames 178/750
# [YOLO] Processing frames 179/750
# [YOLO] Processing frames 180/750
# [YOLO] Processing frames 181/750
# [YOLO] Processing frames 182/750
# [YOLO] Processing frames 183/750
# [YOLO] Processing frames 184/750
# [YOLO] Processing frames 185/750
# [YOLO] Processing frames 186/750
# [YOLO] Processing frames 187/750
# [YOLO] Processing frames 188/750
# [YOLO] Processing frames 189/750
# [YOLO] Processing frames 190/750
# [YOLO] Processing frames 191/750
# [YOLO] Processing frames 192/750
# [YOLO] Processing frames 193/750
# [YOLO] Processing frames 194/750
# [YOLO] Processing frames 195/750
# [YOLO] Processing frames 196/750
# [YOLO] Processing frames 197/750
# [YOLO] Processing frames 198/750
# [YOLO] Processing frames 199/750
# [YOLO] Processing frames 200/750
# [YOLO] Processing frames 201/750
# [YOLO] Processing frames 202/750
# [YOLO] Processing frames 203/750
# [YOLO] Processing frames 204/750
# [YOLO] Processing frames 205/750
# [YOLO] Processing frames 206/750
# [YOLO] Processing frames 207/750
# [YOLO] Processing frames 208/750
# [YOLO] Processing frames 209/750
# [YOLO] Processing frames 210/750
# [YOLO] Processing frames 211/750
# [YOLO] Processing frames 212/750
# [YOLO] Processing frames 213/750
# [YOLO] Processing frames 214/750
# [YOLO] Processing frames 215/750
# [YOLO] Processing frames 216/750
# [YOLO] Processing frames 217/750
# [YOLO] Processing frames 218/750
# [YOLO] Processing frames 219/750
# [YOLO] Processing frames 220/750
# [YOLO] Processing frames 221/750
# [YOLO] Processing frames 222/750
# [YOLO] Processing frames 223/750
# [YOLO] Processing frames 224/750
# [YOLO] Processing frames 225/750
# [YOLO] Processing frames 226/750
# [YOLO] Processing frames 227/750
# [YOLO] Processing frames 228/750
# [YOLO] Processing frames 229/750
# [YOLO] Processing frames 230/750
# [YOLO] Processing frames 231/750
# [YOLO] Processing frames 232/750
# [YOLO] Processing frames 233/750
# [YOLO] Processing frames 234/750
# [YOLO] Processing frames 235/750
# [YOLO] Processing frames 236/750
# [YOLO] Processing frames 237/750
# [YOLO] Processing frames 238/750
# [YOLO] Processing frames 239/750
# [YOLO] Processing frames 240/750
# [YOLO] Processing frames 241/750
# [YOLO] Processing frames 242/750
# [YOLO] Processing frames 243/750
# [YOLO] Processing frames 244/750
# [YOLO] Processing frames 245/750
# [YOLO] Processing frames 246/750
# [YOLO] Processing frames 247/750
# [YOLO] Processing frames 248/750
# [YOLO] Processing frames 249/750
# [YOLO] Processing frames 250/750
# [YOLO] Processing frames 251/750
# [YOLO] Processing frames 252/750
# [YOLO] Processing frames 253/750
# [YOLO] Processing frames 254/750
# [YOLO] Processing frames 255/750
# [YOLO] Processing frames 256/750
# [YOLO] Processing frames 257/750
# [YOLO] Processing frames 258/750
# [YOLO] Processing frames 259/750
# [YOLO] Processing frames 260/750
# [YOLO] Processing frames 261/750
# [YOLO] Processing frames 262/750
# [YOLO] Processing frames 263/750
# [YOLO] Processing frames 264/750
# [YOLO] Processing frames 265/750
# [YOLO] Processing frames 266/750
# [YOLO] Processing frames 267/750
# [YOLO] Processing frames 268/750
# [YOLO] Processing frames 269/750
# [YOLO] Processing frames 270/750
# [YOLO] Processing frames 271/750
# [YOLO] Processing frames 272/750
# [YOLO] Processing frames 273/750
# [YOLO] Processing frames 274/750
# [YOLO] Processing frames 275/750
# [YOLO] Processing frames 276/750
# [YOLO] Processing frames 277/750
# [YOLO] Processing frames 278/750
# [YOLO] Processing frames 279/750
# [YOLO] Processing frames 280/750
# [YOLO] Processing frames 281/750
# [YOLO] Processing frames 282/750
# [YOLO] Processing frames 283/750
# [YOLO] Processing frames 284/750
# [YOLO] Processing frames 285/750
# [YOLO] Processing frames 286/750
# [YOLO] Processing frames 287/750
# [YOLO] Processing frames 288/750
# [YOLO] Processing frames 289/750
# [YOLO] Processing frames 290/750
# [YOLO] Processing frames 291/750
# [YOLO] Processing frames 292/750
# [YOLO] Processing frames 293/750
# [YOLO] Processing frames 294/750
# [YOLO] Processing frames 295/750
# [YOLO] Processing frames 296/750
# [YOLO] Processing frames 297/750
# [YOLO] Processing frames 298/750
# [YOLO] Processing frames 299/750
# [YOLO] Processing frames 300/750
# [YOLO] Processing frames 301/750
# [YOLO] Processing frames 302/750
# [YOLO] Processing frames 303/750
# [YOLO] Processing frames 304/750
# [YOLO] Processing frames 305/750
# [YOLO] Processing frames 306/750
# [YOLO] Processing frames 307/750
# [YOLO] Processing frames 308/750
# [YOLO] Processing frames 309/750
# [YOLO] Processing frames 310/750
# [YOLO] Processing frames 311/750
# [YOLO] Processing frames 312/750
# [YOLO] Processing frames 313/750
# [YOLO] Processing frames 314/750
# [YOLO] Processing frames 315/750
# [YOLO] Processing frames 316/750
# [YOLO] Processing frames 317/750
# [YOLO] Processing frames 318/750
# [YOLO] Processing frames 319/750
# [YOLO] Processing frames 320/750
# [YOLO] Processing frames 321/750
# [YOLO] Processing frames 322/750
# [YOLO] Processing frames 323/750
# [YOLO] Processing frames 324/750
# [YOLO] Processing frames 325/750
# [YOLO] Processing frames 326/750
# [YOLO] Processing frames 327/750
# [YOLO] Processing frames 328/750
# [YOLO] Processing frames 329/750
# [YOLO] Processing frames 330/750
# [YOLO] Processing frames 331/750
# [YOLO] Processing frames 332/750
# [YOLO] Processing frames 333/750
# [YOLO] Processing frames 334/750
# [YOLO] Processing frames 335/750
# [YOLO] Processing frames 336/750
# [YOLO] Processing frames 337/750
# [YOLO] Processing frames 338/750
# [YOLO] Processing frames 339/750
# [YOLO] Processing frames 340/750
# [YOLO] Processing frames 341/750
# [YOLO] Processing frames 342/750
# [YOLO] Processing frames 343/750
# [YOLO] Processing frames 344/750
# [YOLO] Processing frames 345/750
# [YOLO] Processing frames 346/750
# [YOLO] Processing frames 347/750
# [YOLO] Processing frames 348/750
# [YOLO] Processing frames 349/750
# [YOLO] Processing frames 350/750
# [YOLO] Processing frames 351/750
# [YOLO] Processing frames 352/750
# [YOLO] Processing frames 353/750
# [YOLO] Processing frames 354/750
# [YOLO] Processing frames 355/750
# [YOLO] Processing frames 356/750
# [YOLO] Processing frames 357/750
# [YOLO] Processing frames 358/750
# [YOLO] Processing frames 359/750
# [YOLO] Processing frames 360/750
# [YOLO] Processing frames 361/750
# [YOLO] Processing frames 362/750
# [YOLO] Processing frames 363/750
# [YOLO] Processing frames 364/750
# [YOLO] Processing frames 365/750
# [YOLO] Processing frames 366/750
# [YOLO] Processing frames 367/750
# [YOLO] Processing frames 368/750
# [YOLO] Processing frames 369/750
# [YOLO] Processing frames 370/750
# [YOLO] Processing frames 371/750
# [YOLO] Processing frames 372/750
# [YOLO] Processing frames 373/750
# [YOLO] Processing frames 374/750
# [YOLO] Processing frames 375/750
# [YOLO] Processing frames 376/750
# [YOLO] Processing frames 377/750
# [YOLO] Processing frames 378/750
# [YOLO] Processing frames 379/750
# [YOLO] Processing frames 380/750
# [YOLO] Processing frames 381/750
# [YOLO] Processing frames 382/750
# [YOLO] Processing frames 383/750
# [YOLO] Processing frames 384/750
# [YOLO] Processing frames 385/750
# [YOLO] Processing frames 386/750
# [YOLO] Processing frames 387/750
# [YOLO] Processing frames 388/750
# [YOLO] Processing frames 389/750
# [YOLO] Processing frames 390/750
# [YOLO] Processing frames 391/750
# [YOLO] Processing frames 392/750
# [YOLO] Processing frames 393/750
# [YOLO] Processing frames 394/750
# [YOLO] Processing frames 395/750
# [YOLO] Processing frames 396/750
# [YOLO] Processing frames 397/750
# [YOLO] Processing frames 398/750
# [YOLO] Processing frames 399/750
# [YOLO] Processing frames 400/750
# [YOLO] Processing frames 401/750
# [YOLO] Processing frames 402/750
# [YOLO] Processing frames 403/750
# [YOLO] Processing frames 404/750
# [YOLO] Processing frames 405/750
# [YOLO] Processing frames 406/750
# [YOLO] Processing frames 407/750
# [YOLO] Processing frames 408/750
# [YOLO] Processing frames 409/750
# [YOLO] Processing frames 410/750
# [YOLO] Processing frames 411/750
# [YOLO] Processing frames 412/750
# [YOLO] Processing frames 413/750
# [YOLO] Processing frames 414/750
# [YOLO] Processing frames 415/750
# [YOLO] Processing frames 416/750
# [YOLO] Processing frames 417/750
# [YOLO] Processing frames 418/750
# [YOLO] Processing frames 419/750
# [YOLO] Processing frames 420/750
# [YOLO] Processing frames 421/750
# [YOLO] Processing frames 422/750
# [YOLO] Processing frames 423/750
# [YOLO] Processing frames 424/750
# [YOLO] Processing frames 425/750
# [YOLO] Processing frames 426/750
# [YOLO] Processing frames 427/750
# [YOLO] Processing frames 428/750
# [YOLO] Processing frames 429/750
# [YOLO] Processing frames 430/750
# [YOLO] Processing frames 431/750
# [YOLO] Processing frames 432/750
# [YOLO] Processing frames 433/750
# [YOLO] Processing frames 434/750
# [YOLO] Processing frames 435/750
# [YOLO] Processing frames 436/750
# [YOLO] Processing frames 437/750
# [YOLO] Processing frames 438/750
# [YOLO] Processing frames 439/750
# [YOLO] Processing frames 440/750
# [YOLO] Processing frames 441/750
# [YOLO] Processing frames 442/750
# [YOLO] Processing frames 443/750
# [YOLO] Processing frames 444/750
# [YOLO] Processing frames 445/750
# [YOLO] Processing frames 446/750
# [YOLO] Processing frames 447/750
# [YOLO] Processing frames 448/750
# [YOLO] Processing frames 449/750
# [YOLO] Processing frames 450/750
# [YOLO] Processing frames 451/750
# [YOLO] Processing frames 452/750
# [YOLO] Processing frames 453/750
# [YOLO] Processing frames 454/750
# [YOLO] Processing frames 455/750
# [YOLO] Processing frames 456/750
# [YOLO] Processing frames 457/750
# [YOLO] Processing frames 458/750
# [YOLO] Processing frames 459/750
# [YOLO] Processing frames 460/750
# [YOLO] Processing frames 461/750
# [YOLO] Processing frames 462/750
# [YOLO] Processing frames 463/750
# [YOLO] Processing frames 464/750
# [YOLO] Processing frames 465/750
# [YOLO] Processing frames 466/750
# [YOLO] Processing frames 467/750
# [YOLO] Processing frames 468/750
# [YOLO] Processing frames 469/750
# [YOLO] Processing frames 470/750
# [YOLO] Processing frames 471/750
# [YOLO] Processing frames 472/750
# [YOLO] Processing frames 473/750
# [YOLO] Processing frames 474/750
# [YOLO] Processing frames 475/750
# [YOLO] Processing frames 476/750
# [YOLO] Processing frames 477/750
# [YOLO] Processing frames 478/750
# [YOLO] Processing frames 479/750
# [YOLO] Processing frames 480/750
# [YOLO] Processing frames 481/750
# [YOLO] Processing frames 482/750
# [YOLO] Processing frames 483/750
# [YOLO] Processing frames 484/750
# [YOLO] Processing frames 485/750
# [YOLO] Processing frames 486/750
# [YOLO] Processing frames 487/750
# [YOLO] Processing frames 488/750
# [YOLO] Processing frames 489/750
# [YOLO] Processing frames 490/750
# [YOLO] Processing frames 491/750
# [YOLO] Processing frames 492/750
# [YOLO] Processing frames 493/750
# [YOLO] Processing frames 494/750
# [YOLO] Processing frames 495/750
# [YOLO] Processing frames 496/750
# [YOLO] Processing frames 497/750
# [YOLO] Processing frames 498/750
# [YOLO] Processing frames 499/750
# [YOLO] Processing frames 500/750
# [YOLO] Processing frames 501/750
# [YOLO] Processing frames 502/750
# [YOLO] Processing frames 503/750
# [YOLO] Processing frames 504/750
# [YOLO] Processing frames 505/750
# [YOLO] Processing frames 506/750
# [YOLO] Processing frames 507/750
# [YOLO] Processing frames 508/750
# [YOLO] Processing frames 509/750
# [YOLO] Processing frames 510/750
# [YOLO] Processing frames 511/750
# [YOLO] Processing frames 512/750
# [YOLO] Processing frames 513/750
# [YOLO] Processing frames 514/750
# [YOLO] Processing frames 515/750
# [YOLO] Processing frames 516/750
# [YOLO] Processing frames 517/750
# [YOLO] Processing frames 518/750
# [YOLO] Processing frames 519/750
# [YOLO] Processing frames 520/750
# [YOLO] Processing frames 521/750
# [YOLO] Processing frames 522/750
# [YOLO] Processing frames 523/750
# [YOLO] Processing frames 524/750
# [YOLO] Processing frames 525/750
# [YOLO] Processing frames 526/750
# [YOLO] Processing frames 527/750
# [YOLO] Processing frames 528/750
# [YOLO] Processing frames 529/750
# [YOLO] Processing frames 530/750
# [YOLO] Processing frames 531/750
# [YOLO] Processing frames 532/750
# [YOLO] Processing frames 533/750
# [YOLO] Processing frames 534/750
# [YOLO] Processing frames 535/750
# [YOLO] Processing frames 536/750
# [YOLO] Processing frames 537/750
# [YOLO] Processing frames 538/750
# [YOLO] Processing frames 539/750
# [YOLO] Processing frames 540/750
# [YOLO] Processing frames 541/750
# [YOLO] Processing frames 542/750
# [YOLO] Processing frames 543/750
# [YOLO] Processing frames 544/750
# [YOLO] Processing frames 545/750
# [YOLO] Processing frames 546/750
# [YOLO] Processing frames 547/750
# [YOLO] Processing frames 548/750
# [YOLO] Processing frames 549/750
# [YOLO] Processing frames 550/750
# [YOLO] Processing frames 551/750
# [YOLO] Processing frames 552/750
# [YOLO] Processing frames 553/750
# [YOLO] Processing frames 554/750
# [YOLO] Processing frames 555/750
# [YOLO] Processing frames 556/750
# [YOLO] Processing frames 557/750
# [YOLO] Processing frames 558/750
# [YOLO] Processing frames 559/750
# [YOLO] Processing frames 560/750
# [YOLO] Processing frames 561/750
# [YOLO] Processing frames 562/750
# [YOLO] Processing frames 563/750
# [YOLO] Processing frames 564/750
# [YOLO] Processing frames 565/750
# [YOLO] Processing frames 566/750
# [YOLO] Processing frames 567/750
# [YOLO] Processing frames 568/750
# [YOLO] Processing frames 569/750
# [YOLO] Processing frames 570/750
# [YOLO] Processing frames 571/750
# [YOLO] Processing frames 572/750
# [YOLO] Processing frames 573/750
# [YOLO] Processing frames 574/750
# [YOLO] Processing frames 575/750
# [YOLO] Processing frames 576/750
# [YOLO] Processing frames 577/750
# [YOLO] Processing frames 578/750
# [YOLO] Processing frames 579/750
# [YOLO] Processing frames 580/750
# [YOLO] Processing frames 581/750
# [YOLO] Processing frames 582/750
# [YOLO] Processing frames 583/750
# [YOLO] Processing frames 584/750
# [YOLO] Processing frames 585/750
# [YOLO] Processing frames 586/750
# [YOLO] Processing frames 587/750
# [YOLO] Processing frames 588/750
# [YOLO] Processing frames 589/750
# [YOLO] Processing frames 590/750
# [YOLO] Processing frames 591/750
# [YOLO] Processing frames 592/750
# [YOLO] Processing frames 593/750
# [YOLO] Processing frames 594/750
# [YOLO] Processing frames 595/750
# [YOLO] Processing frames 596/750
# [YOLO] Processing frames 597/750
# [YOLO] Processing frames 598/750
# [YOLO] Processing frames 599/750
# [YOLO] Processing frames 600/750
# [YOLO] Processing frames 601/750
# [YOLO] Processing frames 602/750
# [YOLO] Processing frames 603/750
# [YOLO] Processing frames 604/750
# [YOLO] Processing frames 605/750
# [YOLO] Processing frames 606/750
# [YOLO] Processing frames 607/750
# [YOLO] Processing frames 608/750
# [YOLO] Processing frames 609/750
# [YOLO] Processing frames 610/750
# [YOLO] Processing frames 611/750
# [YOLO] Processing frames 612/750
# [YOLO] Processing frames 613/750
# [YOLO] Processing frames 614/750
# [YOLO] Processing frames 615/750
# [YOLO] Processing frames 616/750
# [YOLO] Processing frames 617/750
# [YOLO] Processing frames 618/750
# [YOLO] Processing frames 619/750
# [YOLO] Processing frames 620/750
# [YOLO] Processing frames 621/750
# [YOLO] Processing frames 622/750
# [YOLO] Processing frames 623/750
# [YOLO] Processing frames 624/750
# [YOLO] Processing frames 625/750
# [YOLO] Processing frames 626/750
# [YOLO] Processing frames 627/750
# [YOLO] Processing frames 628/750
# [YOLO] Processing frames 629/750
# [YOLO] Processing frames 630/750
# [YOLO] Processing frames 631/750
# [YOLO] Processing frames 632/750
# [YOLO] Processing frames 633/750
# [YOLO] Processing frames 634/750
# [YOLO] Processing frames 635/750
# [YOLO] Processing frames 636/750
# [YOLO] Processing frames 637/750
# [YOLO] Processing frames 638/750
# [YOLO] Processing frames 639/750
# [YOLO] Processing frames 640/750
# [YOLO] Processing frames 641/750
# [YOLO] Processing frames 642/750
# [YOLO] Processing frames 643/750
# [YOLO] Processing frames 644/750
# [YOLO] Processing frames 645/750
# [YOLO] Processing frames 646/750
# [YOLO] Processing frames 647/750
# [YOLO] Processing frames 648/750
# [YOLO] Processing frames 649/750
# [YOLO] Processing frames 650/750
# [YOLO] Processing frames 651/750
# [YOLO] Processing frames 652/750
# [YOLO] Processing frames 653/750
# [YOLO] Processing frames 654/750
# [YOLO] Processing frames 655/750
# [YOLO] Processing frames 656/750
# [YOLO] Processing frames 657/750
# [YOLO] Processing frames 658/750
# [YOLO] Processing frames 659/750
# [YOLO] Processing frames 660/750
# [YOLO] Processing frames 661/750
# [YOLO] Processing frames 662/750
# [YOLO] Processing frames 663/750
# [YOLO] Processing frames 664/750
# [YOLO] Processing frames 665/750
# [YOLO] Processing frames 666/750
# [YOLO] Processing frames 667/750
# [YOLO] Processing frames 668/750
# [YOLO] Processing frames 669/750
# [YOLO] Processing frames 670/750
# [YOLO] Processing frames 671/750
# [YOLO] Processing frames 672/750
# [YOLO] Processing frames 673/750
# [YOLO] Processing frames 674/750
# [YOLO] Processing frames 675/750
# [YOLO] Processing frames 676/750
# [YOLO] Processing frames 677/750
# [YOLO] Processing frames 678/750
# [YOLO] Processing frames 679/750
# [YOLO] Processing frames 680/750
# [YOLO] Processing frames 681/750
# [YOLO] Processing frames 682/750
# [YOLO] Processing frames 683/750
# [YOLO] Processing frames 684/750
# [YOLO] Processing frames 685/750
# [YOLO] Processing frames 686/750
# [YOLO] Processing frames 687/750
# [YOLO] Processing frames 688/750
# [YOLO] Processing frames 689/750
# [YOLO] Processing frames 690/750
# [YOLO] Processing frames 691/750
# [YOLO] Processing frames 692/750
# [YOLO] Processing frames 693/750
# [YOLO] Processing frames 694/750
# [YOLO] Processing frames 695/750
# [YOLO] Processing frames 696/750
# [YOLO] Processing frames 697/750
# [YOLO] Processing frames 698/750
# [YOLO] Processing frames 699/750
# [YOLO] Processing frames 700/750
# [YOLO] Processing frames 701/750
# [YOLO] Processing frames 702/750
# [YOLO] Processing frames 703/750
# [YOLO] Processing frames 704/750
# [YOLO] Processing frames 705/750
# [YOLO] Processing frames 706/750
# [YOLO] Processing frames 707/750
# [YOLO] Processing frames 708/750
# [YOLO] Processing frames 709/750
# [YOLO] Processing frames 710/750
# [YOLO] Processing frames 711/750
# [YOLO] Processing frames 712/750
# [YOLO] Processing frames 713/750
# [YOLO] Processing frames 714/750
# [YOLO] Processing frames 715/750
# [YOLO] Processing frames 716/750
# [YOLO] Processing frames 717/750
# [YOLO] Processing frames 718/750
# [YOLO] Processing frames 719/750
# [YOLO] Processing frames 720/750
# [YOLO] Processing frames 721/750
# [YOLO] Processing frames 722/750
# [YOLO] Processing frames 723/750
# [YOLO] Processing frames 724/750
# [YOLO] Processing frames 725/750
# [YOLO] Processing frames 726/750
# [YOLO] Processing frames 727/750
# [YOLO] Processing frames 728/750
# [YOLO] Processing frames 729/750
# [YOLO] Processing frames 730/750
# [YOLO] Processing frames 731/750
# [YOLO] Processing frames 732/750
# [YOLO] Processing frames 733/750
# [YOLO] Processing frames 734/750
# [YOLO] Processing frames 735/750
# [YOLO] Processing frames 736/750
# [YOLO] Processing frames 737/750
# [YOLO] Processing frames 738/750
# [YOLO] Processing frames 739/750
# [YOLO] Processing frames 740/750
# [YOLO] Processing frames 741/750
# [YOLO] Processing frames 742/750
# [YOLO] Processing frames 743/750
# [YOLO] Processing frames 744/750
# [YOLO] Processing frames 745/750
# [YOLO] Processing frames 746/750
# [YOLO] Processing frames 747/750
# [YOLO] Processing frames 748/750
# [YOLO] Processing frames 749/750
# [YOLO] Processing frames 750/750
# Detections completed, building tracks...
# Saving 750 frames to stub...
# Stub saved successfully to stubs/track_stubs.pkl

# %%
# Step 3: Add position tracking
tracker.add_position_to_tracks(tracks)

# Pad tracks to match video length
while len(tracks["players"]) < len(video_frames):
    tracks["players"].append({})
    tracks["ball"].append({})
    tracks["referees"].append({})

# %%
# Step 4: Camera movement estimation
print("Setting up camera movement...")
camera_movement_estimator = CameraMovementEstimator(video_frames[0])
camera_movement_per_frame = [[0, 0] for _ in range(len(video_frames))]
camera_movement_estimator.add_adjust_positions_to_tracks(tracks, camera_movement_per_frame)
# Out:
# Setting up camera movement...

# %%
# Step 5: View transformation
print("Applying view transformation...")
view_transformer = ViewTransformer()
view_transformer.add_transformed_position_to_tracks(tracks)
# Out:
# Applying view transformation...

# %%
# Step 6: Interpolate ball positions
print("Interpolating ball positions...")
tracks["ball"] = tracker.interpolate_ball_positions(tracks["ball"])
# Out:
# Interpolating ball positions...

# %%
# Step 7: Speed and distance estimation
print("Estimating speed and distance...")
speed_and_distance_estimator = SpeedAndDistance_Estimator()
speed_and_distance_estimator.add_speed_and_distance_to_tracks(tracks)
# Out:
# Estimating speed and distance...

# %%
# Step 8: Team assignment
print("Assigning player teams...")
team_assigner = TeamAssigner()

# Find the first frame that actually has player detections
first_player_frame = None
for i, player_track in enumerate(tracks["players"]):
    if len(player_track) > 0:
        first_player_frame = i
        break

if first_player_frame is None:
    print("No player detections found in any frame – skipping team assignment.")
else:
    # Use that frame to learn team colors
    team_assigner.assign_team_color(
        video_frames[first_player_frame],
        tracks["players"][first_player_frame]
    )

    # Assign team + color for every frame
    for frame_num, player_track in enumerate(tracks['players']):
        for player_id, track in player_track.items():
            team = team_assigner.get_player_team(
                video_frames[frame_num],
                track['bbox'],
                player_id
            )
            tracks['players'][frame_num][player_id]['team'] = team
            tracks['players'][frame_num][player_id]['team_color'] = team_assigner.team_colors[team]
# Out:
# Assigning player teams...

# %%
# Step 9: Ball possession assignment
print("Assigning ball possession...")
player_ball_assigner = PlayerBallAssigner()
team_ball_control = []
for frame_num, player_track in enumerate(tracks['players']):
    ball_bbox = tracks['ball'][frame_num][1]['bbox'] if tracks['ball'][frame_num] else None
    assigned_player = player_ball_assigner.assign_ball_to_player(player_track, ball_bbox)
    
    if assigned_player != -1:
        tracks['players'][frame_num][assigned_player]['has_ball'] = True
        team_ball_control.append(tracks['players'][frame_num][assigned_player].get('team', 0))
    else:
        team_ball_control.append(0)
else:
    team_ball_control.append(0)
# Out:
# Assigning ball possession...

# %%
team_ball_control = np.array(team_ball_control).astype(int).reshape(-1)

if len(team_ball_control) < len(video_frames):
    padding = len(video_frames) - len(team_ball_control)
    team_ball_control = np.concatenate([team_ball_control, np.zeros(padding, dtype=int)])
elif len(team_ball_control) > len(video_frames):
    team_ball_control = team_ball_control[:len(video_frames)]

# %%
# Step 10: Draw annotations on video frames
print("Drawing annotations...")
output_video_frames = tracker.draw_annotations(video_frames, tracks)

print("Drawing camera movement...")
output_video_frames = camera_movement_estimator.draw_camera_movement(output_video_frames, camera_movement_per_frame)

print("Drawing speed and distance...")
output_video_frames = speed_and_distance_estimator.draw_speed_and_distance(output_video_frames, tracks)
# Out:
# Drawing annotations...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Step 10: Draw annotations on video frames
#       2 print("Drawing annotations...")
# ----> 3 output_video_frames = tracker.draw_annotations(video_frames, tracks)
#       5 print("Drawing camera movement...")
#       6 output_video_frames = camera_movement_estimator.draw_camera_movement(output_video_frames, camera_movement_per_frame)
#
# TypeError: Tracker.draw_annotations() missing 1 required positional argument: 'team_ball_control'

# %%
# Step 10: Draw annotations on video frames
print("Drawing annotations...")
output_video_frames = tracker.draw_annotations(video_frames, tracks, team_ball_control)

print("Drawing camera movement...")
output_video_frames = camera_movement_estimator.draw_camera_movement(output_video_frames, camera_movement_per_frame)

print("Drawing speed and distance...")
output_video_frames = speed_and_distance_estimator.draw_speed_and_distance(output_video_frames, tracks)
# Out:
# Drawing annotations...
# Drawing camera movement...
# Drawing speed and distance...

# %%
# Step 11: Save the output video
print("Saving video...")
save_video(output_video_frames, OUTPUT_VIDEO_PATH)
print(f"✓ Video saved to {OUTPUT_VIDEO_PATH}")
# Out:
# Saving video...
# FFmpeg not available, using OpenCV...
#   Written 100/750 frames...
#   Written 200/750 frames...
#   Written 300/750 frames...
#   Written 400/750 frames...
#   Written 500/750 frames...
#   Written 600/750 frames...
#   Written 700/750 frames...
# ✓ Video saved to output_videos/output_video.avi
# ✓ Video saved to output_videos/output_video.avi

# %% [markdown]
# ## Usage Instructions
#
# **For Different Videos:**
# 1. Place your new video in the `input_videos/` folder
# 2. Change `selected_index` in the video selection cell (e.g., 0 for first video, 1 for second, etc.)
# 3. Re-run the notebook from the video selection cell onward
# 4. Optionally set `READ_FROM_STUB = True` for faster processing if the video content is similar
#
# **Performance Tips:**
# - Processing takes 10-15 minutes on CPU for a 30-second video
# - Use `READ_FROM_STUB = True` after first run to skip detection
# - For GPU acceleration, ensure CUDA is available
