# %%
import roboflow
print(roboflow.__version__)
# Out:
# 1.2.16

# %% [markdown]
# ## Get Dataset from Roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="4jGHN6ym6mClSt6rAEIt")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:01<00:00, 1007.73it/s]

# %%
# get dataset Location
dataset.location
# Out:
# 'c:\\Users\\fajayi\\COMP-3704-Neural_Networks_and_Deep_Learning_Notebook\\Real-Time-Football-Player-Tactics-Tracking-Using-Deep-Learning\\training\\football-players-detection-1'

# %%
# import library called shutil to make required directory to avoid crashing
import shutil #it helps to move and copy files in our machine using python

# %%
shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train')

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test')

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# ## Training

# %%
# !yolo task=detect mode=train model=yolo26x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
